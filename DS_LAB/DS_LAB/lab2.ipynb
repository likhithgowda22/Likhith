# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('auto-mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8           NaN       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8           NaN       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8           NaN       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model-year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    3
# horsepower      2
# weight          0
# acceleration    0
# model-year      0
# dtype: int64

# %%
df['displacement']=df['displacement'].fillna(df['displacement'].mean())

# %%
df['horsepower']=df['horsepower'].fillna(df['horsepower'].mean())

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model-year      0
# dtype: int64

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8    192.548101       130.0    3504          12.0
# 1    15.0          8    350.000000       165.0    3693          11.5
# 2    18.0          8    192.548101       150.0    3436          11.0
# 3    16.0          8    304.000000       150.0    3433          12.0
# 4    17.0          8    192.548101       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4    140.000000        86.0    2790          15.6
# 394  44.0          4     97.000000        52.0    2130          24.6
# 395  32.0          4    135.000000        84.0    2295          11.6
# 396  28.0          4    120.000000        79.0    2625          18.6
# 397  31.0          4    119.000000        82.0    2720          19.4
#
#      model-year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
c=[['mpg','displacement','horsepower','acceleration']]

# %%
for i in c:
    
    sb.histplot(df[i])
    plt.show()
# Out:
# C:\Users\sindh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.scatterplot(x='acceleration' , y='mpg',data=df)
plt.show()

# %%
sb.countplot(x=df['acceleration'])
# Out:
# <Axes: xlabel='acceleration', ylabel='count'>

# %%
sb.pointplot(x=df['cylinders'] , y=df['mpg'] ,data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>
